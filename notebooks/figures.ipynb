# %%
import pandas as pd

# %% [markdown]
# ## Overlap fraction and 3D distance comparison:
# ### Example of Fig.1C, i.e. 51a-51b (within TAD) versus 51b-52 (between TADs) in ESC; see graph 1c.

# %%
# Loading data
esc_df = pd.read_csv("../assays/ESC/Experiment_A_merged_df.csv")
npc_df = pd.read_csv("../assays/NPC/Experiment_B_merged_df.csv")
ncxnpc_df = pd.read_csv("../assays/ncxNPC/Experiment_C_merged_df.csv")
ctcf_aid_ctl_df = pd.read_csv("../assays/CTCF-AID_AUX-CTL/Experiment_D_merged_df.csv")
ctcf_aid_aux_df = pd.read_csv("../assays/CTCF-AID_AUX/Experiment_E_merged_df.csv")
rad21_aid_ctl_df = pd.read_csv("../assays/RAD21-AID_AUX-CTL/Experiment_F_merged_df.csv")
rad21_aid_aux_df = pd.read_csv("../assays/RAD21-AID_AUX/Experiment_G_merged_df.csv")
esc_ctl_df = pd.read_csv("../assays/ESC_TSA-CTL/Experiment_H_merged_df.csv")
esc_tsa_df = pd.read_csv("../assays/ESC_TSA/Experiment_I_merged_df.csv")

# %%
# Selecting some data
probes_sel = ["51a", "51b", "52"]
esc_subset = esc_df[(esc_df['Probe Ch0'].isin(probes_sel)) & (esc_df['Probe Ch1'].isin(probes_sel))]
esc_subset.head()
# Out:
#                                              Image Name      Date  \
# 2731  20180723_RI510_ESC_51b_51a_SIR_2C_ALN_THR_3.om...  20180723
# 2732  20180723_RI510_ESC_51b_51a_SIR_2C_ALN_THR_3.om...  20180723
# 2733  20180723_RI510_ESC_51b_51a_SIR_2C_ALN_THR_3.om...  20180723
# 2734  20180723_RI510_ESC_51b_51a_SIR_2C_ALN_THR_3.om...  20180723
# 2771  20180723_RI510_ESC_51b_52_SIR_2C_ALN_THR_8.ome...  20180723
#
#      Refractive Index Cell Line Name Probe Ch0 Sir Tag Thresholded Tag  \
# 2731            RI510            ESC       51b     SIR             THR
# 2732            RI510            ESC       51b     SIR             THR
# 2733            RI510            ESC       51b     SIR             THR
# 2734            RI510            ESC       51b     SIR             THR
# 2771            RI510            ESC       51b     SIR             THR
#
#       Image Number Label Ch0 Characteristics [Organism]  ...  solidity  \
# 2731             3  ATTO-565               Mus musculus  ...  0.570613
# 2732             3  ATTO-565               Mus musculus  ...       NaN
# 2733             3  ATTO-565               Mus musculus  ...       NaN
# 2734             3  ATTO-565               Mus musculus  ...       NaN
# 2771             8  ATTO-565               Mus musculus  ...  0.610687
#
#       volume volume_units overlap_fraction distance_x distance_y distance_z  \
# 2731  0.0800     micron^3              NaN        NaN        NaN        NaN
# 2732  0.0160     micron^3              NaN        NaN        NaN        NaN
# 2733  0.0128     micron^3              NaN        NaN        NaN        NaN
# 2734  0.0480     micron^3              NaN        NaN        NaN        NaN
# 2771  0.0640     micron^3              NaN        NaN        NaN        NaN
#
#       distance3d  distance_units                Roi Name
# 2731         NaN             NaN     ch-1_domain_label-1
# 2732         NaN             NaN  ch-1_subdomain_label-2
# 2733         NaN             NaN  ch-1_subdomain_label-3
# 2734         NaN             NaN  ch-1_subdomain_label-4
# 2771         NaN             NaN     ch-0_domain_label-1
#
# [5 rows x 71 columns]

# %%
# Plotting overlap fraction
esc_subset.boxplot(column="overlap_fraction", by=["Probe Ch0", "Probe Ch1"])
# Out:
# <AxesSubplot:title={'center':'overlap_fraction'}, xlabel='[Probe Ch0, Probe Ch1]'>

# %%
# Plotting 3D-distance
esc_subset.boxplot(column="distance3d", by=["Probe Ch0", "Probe Ch1"])
# Out:
# <AxesSubplot:title={'center':'distance3d'}, xlabel='[Probe Ch0, Probe Ch1]'>

# %% [markdown]
# ### Example of Fig.2, i.e. 21-22 in ESC (split TAD) versus 21-22 in NPC (merge TAD); see graph 2g.

# %%
probes_sel = ["21", "22", 21, 22]
esc_subset = esc_df[(esc_df['Probe Ch0'].isin(probes_sel)) & (esc_df['Probe Ch1'].isin(probes_sel))]
esc_subset.head()
# Out:
#                                              Image Name      Date  \
# 2961  20180329_RI510_ESC_22_21_SIR_2C_ALN_THR_39.ome...  20180329
# 2962  20180329_RI510_ESC_22_21_SIR_2C_ALN_THR_39.ome...  20180329
# 2963  20180329_RI510_ESC_22_21_SIR_2C_ALN_THR_39.ome...  20180329
# 2964  20180329_RI510_ESC_22_21_SIR_2C_ALN_THR_39.ome...  20180329
# 2965  20180329_RI510_ESC_22_21_SIR_2C_ALN_THR_39.ome...  20180329
#
#      Refractive Index Cell Line Name Probe Ch0 Sir Tag Thresholded Tag  \
# 2961            RI510            ESC        22     SIR             THR
# 2962            RI510            ESC        22     SIR             THR
# 2963            RI510            ESC        22     SIR             THR
# 2964            RI510            ESC        22     SIR             THR
# 2965            RI510            ESC        22     SIR             THR
#
#       Image Number Label Ch0 Characteristics [Organism]  ...  solidity  \
# 2961            39  ATTO-565               Mus musculus  ...  0.558908
# 2962            39  ATTO-565               Mus musculus  ...       NaN
# 2963            39  ATTO-565               Mus musculus  ...       NaN
# 2964            39  ATTO-565               Mus musculus  ...       NaN
# 2965            39  ATTO-565               Mus musculus  ...  0.542587
#
#       volume volume_units overlap_fraction distance_x distance_y distance_z  \
# 2961  0.1556     micron^3              NaN        NaN        NaN        NaN
# 2962  0.0282     micron^3              NaN        NaN        NaN        NaN
# 2963  0.0864     micron^3              NaN        NaN        NaN        NaN
# 2964  0.0410     micron^3              NaN        NaN        NaN        NaN
# 2965  0.2064     micron^3              NaN        NaN        NaN        NaN
#
#       distance3d  distance_units                Roi Name
# 2961         NaN             NaN     ch-0_domain_label-1
# 2962         NaN             NaN  ch-0_subdomain_label-2
# 2963         NaN             NaN  ch-0_subdomain_label-3
# 2964         NaN             NaN  ch-0_subdomain_label-4
# 2965         NaN             NaN     ch-1_domain_label-1
#
# [5 rows x 71 columns]

# %%
npc_subset = npc_df[(npc_df['Probe Ch0'].isin(probes_sel)) & (npc_df['Probe Ch1'].isin(probes_sel))]
# Out:
#                                              Image Name      Date  \
# 2099  20190122_RI510_NPC_22_21_SIR_2C_ALN_THR_23.ome...  20190122
# 2100  20190122_RI510_NPC_22_21_SIR_2C_ALN_THR_23.ome...  20190122
# 2101  20190122_RI510_NPC_22_21_SIR_2C_ALN_THR_23.ome...  20190122
# 2102  20190122_RI510_NPC_22_21_SIR_2C_ALN_THR_23.ome...  20190122
# 2103  20190122_RI510_NPC_22_21_SIR_2C_ALN_THR_23.ome...  20190122
#
#      Refractive Index Cell Line Name Probe Ch0 Sir Tag Thresholded Tag  \
# 2099            RI510            NPC        22     SIR             THR
# 2100            RI510            NPC        22     SIR             THR
# 2101            RI510            NPC        22     SIR             THR
# 2102            RI510            NPC        22     SIR             THR
# 2103            RI510            NPC        22     SIR             THR
#
#       Image Number Label Ch0 Characteristics [Organism]  ...  solidity  \
# 2099            23  ATTO-565               Mus musculus  ...  0.532822
# 2100            23  ATTO-565               Mus musculus  ...       NaN
# 2101            23  ATTO-565               Mus musculus  ...       NaN
# 2102            23  ATTO-565               Mus musculus  ...       NaN
# 2103            23  ATTO-565               Mus musculus  ...  0.704722
#
#       volume volume_units                Roi Name overlap_fraction distance_x  \
# 2099  0.1250     micron^3     ch-0_domain_label-1              NaN        NaN
# 2100  0.0298     micron^3  ch-0_subdomain_label-2              NaN        NaN
# 2101  0.0276     micron^3  ch-0_subdomain_label-3              NaN        NaN
# 2102  0.0676     micron^3  ch-0_subdomain_label-4              NaN        NaN
# 2103  0.2000     micron^3     ch-1_domain_label-1              NaN        NaN
#
#      distance_y  distance_z  distance3d  distance_units
# 2099        NaN         NaN         NaN             NaN
# 2100        NaN         NaN         NaN             NaN
# 2101        NaN         NaN         NaN             NaN
# 2102        NaN         NaN         NaN             NaN
# 2103        NaN         NaN         NaN             NaN
#
# [5 rows x 71 columns]

# %%
ncxnpc_subset = ncxnpc_df[(ncxnpc_df['Probe Ch0'].isin(probes_sel)) & (ncxnpc_df['Probe Ch1'].isin(probes_sel))]
ncxnpc_subset.head()
# Out:
#                                            Image Name      Date  \
# 7   20180809_RI516_ncxNPC_22_21_SIR_2C_ALN_THR_13....  20180809
# 8   20180809_RI516_ncxNPC_22_21_SIR_2C_ALN_THR_13....  20180809
# 9   20180809_RI516_ncxNPC_22_21_SIR_2C_ALN_THR_13....  20180809
# 10  20180809_RI516_ncxNPC_22_21_SIR_2C_ALN_THR_13....  20180809
# 11  20180809_RI516_ncxNPC_22_21_SIR_2C_ALN_THR_13....  20180809
#
#    Refractive Index Cell Line Name  Probe Ch0  Probe Ch1 Sir Tag  \
# 7             RI516         ncxNPC         22         21     SIR
# 8             RI516         ncxNPC         22         21     SIR
# 9             RI516         ncxNPC         22         21     SIR
# 10            RI516         ncxNPC         22         21     SIR
# 11            RI516         ncxNPC         22         21     SIR
#
#    Number Of Channels Aligned Tag Thresholded Tag  ...  solidity  volume  \
# 7                  2C         ALN             THR  ...  0.713320  0.2110
# 8                  2C         ALN             THR  ...       NaN  0.2002
# 9                  2C         ALN             THR  ...       NaN  0.0108
# 10                 2C         ALN             THR  ...  0.844796  0.1818
# 11                 2C         ALN             THR  ...       NaN  0.1818
#
#    volume_units overlap_fraction  distance_x distance_y distance_z distance3d  \
# 7      micron^3              NaN         NaN        NaN        NaN        NaN
# 8      micron^3              NaN         NaN        NaN        NaN        NaN
# 9      micron^3              NaN         NaN        NaN        NaN        NaN
# 10     micron^3              NaN         NaN        NaN        NaN        NaN
# 11     micron^3              NaN         NaN        NaN        NaN        NaN
#
#    distance_units                Roi Name
# 7             NaN     ch-0_domain_label-1
# 8             NaN  ch-0_subdomain_label-2
# 9             NaN  ch-0_subdomain_label-3
# 10            NaN     ch-1_domain_label-1
# 11            NaN  ch-1_subdomain_label-2
#
# [5 rows x 71 columns]

# %%
# Plotting 3D-distance
pd.concat([esc_subset, npc_subset, ncxnpc_subset]).boxplot(column="distance3d",
                                                           by=["Cell Line Name", "Probe Ch0", "Probe Ch1"])
# Out:
# <AxesSubplot:title={'center':'distance3d'}, xlabel='[Cell Line Name, Probe Ch0, Probe Ch1]'>

# %% [markdown]
# ### Examples of Fig.3: 101-102a (between TADs) for CTCF-AID-control versus CTCF-AID-AUX; and 102a-102b (within TAD) for RAD21-AID-control versus RAD21-AID-AUX; see graph 3c.

# %%
probes_sel = ["101", "102a", "102b"]

ctcf_aid_ctl_subset = ctcf_aid_ctl_df[(ctcf_aid_ctl_df['Probe Ch0'].isin(probes_sel)) & (ctcf_aid_ctl_df['Probe Ch1'].isin(probes_sel))]
ctcf_aid_ctl_subset.head()
ctcf_aid_aux_subset = ctcf_aid_aux_df[
    (ctcf_aid_aux_df['Probe Ch0'].isin(probes_sel)) & (ctcf_aid_aux_df['Probe Ch1'].isin(probes_sel))]
ctcf_aid_aux_subset.head()

rad21_aid_ctl_subset = rad21_aid_ctl_df[
    (rad21_aid_ctl_df['Probe Ch0'].isin(probes_sel)) & (rad21_aid_ctl_df['Probe Ch1'].isin(probes_sel))]
rad21_aid_ctl_subset.head()
rad21_aid_aux_subset = rad21_aid_aux_df[
    (rad21_aid_aux_df['Probe Ch0'].isin(probes_sel)) & (rad21_aid_aux_df['Probe Ch1'].isin(probes_sel))]
rad21_aid_aux_subset.head()
# Out:
#                                            Image Name      Date  \
# 76  20200721_RI512_RAD21-AID_AUX_102a_102b_SIR_2C_...  20200721
# 77  20200721_RI512_RAD21-AID_AUX_102a_102b_SIR_2C_...  20200721
# 78  20200721_RI512_RAD21-AID_AUX_102a_102b_SIR_2C_...  20200721
# 79  20200721_RI512_RAD21-AID_AUX_102a_102b_SIR_2C_...  20200721
# 80  20200721_RI512_RAD21-AID_AUX_102a_102b_SIR_2C_...  20200721
#
#    Refractive Index Cell Line Name Protocol Probe Ch0 Probe Ch1 Sir Tag  \
# 76            RI512      RAD21-AID      AUX      102a      102b     SIR
# 77            RI512      RAD21-AID      AUX      102a      102b     SIR
# 78            RI512      RAD21-AID      AUX      102a      102b     SIR
# 79            RI512      RAD21-AID      AUX      102a      102b     SIR
# 80            RI512      RAD21-AID      AUX      102a      102b     SIR
#
#    Number Of Channels Aligned Tag  ...  solidity  volume volume_units  \
# 76                 2C         ALN  ...  0.813880  0.0516     micron^3
# 77                 2C         ALN  ...       NaN  0.0516     micron^3
# 78                 2C         ALN  ...  0.474662  0.1124     micron^3
# 79                 2C         ALN  ...       NaN  0.0506     micron^3
# 80                 2C         ALN  ...       NaN  0.0262     micron^3
#
#    overlap_fraction distance_x  distance_y distance_z distance3d  \
# 76              NaN        NaN         NaN        NaN        NaN
# 77              NaN        NaN         NaN        NaN        NaN
# 78              NaN        NaN         NaN        NaN        NaN
# 79              NaN        NaN         NaN        NaN        NaN
# 80              NaN        NaN         NaN        NaN        NaN
#
#    distance_units                Roi Name
# 76            NaN     ch-0_domain_label-1
# 77            NaN  ch-0_subdomain_label-2
# 78            NaN     ch-1_domain_label-1
# 79            NaN  ch-1_subdomain_label-2
# 80            NaN  ch-1_subdomain_label-3
#
# [5 rows x 74 columns]

# %%
pd.concat([ctcf_aid_ctl_subset, ctcf_aid_aux_subset]).boxplot(column="overlap_fraction", by=["Protocol", "Probe Ch0", "Probe Ch1"], rot=45)

pd.concat([rad21_aid_ctl_subset, rad21_aid_aux_subset]).boxplot(column="overlap_fraction", by=["Protocol", "Probe Ch0", "Probe Ch1"], rot=45)

pd.concat([ctcf_aid_ctl_subset, ctcf_aid_aux_subset]).boxplot(column="distance3d", by=["Protocol", "Probe Ch0", "Probe Ch1"], rot=45)

pd.concat([rad21_aid_ctl_subset, rad21_aid_aux_subset]).boxplot(column="distance3d", by=["Protocol", "Probe Ch0", "Probe Ch1"], rot=45)
# Out:
# <AxesSubplot:title={'center':'distance3d'}, xlabel='[Protocol, Probe Ch0, Probe Ch1]'>

# %% [markdown]
# ## CND/subdomain number comparisons:
#
# ### Examples of Fig.4: probes 32; 62; and 81 in ESC-Control versus ESC-TSA; see graph 4g.

# %%
probes_sel = ["32", "62", "81", "101", "112"]

esc_ctl_subset = esc_ctl_df[(esc_ctl_df['Probe Ch0'].isin(probes_sel)) & \
                            (esc_ctl_df['roi_type'] == "subdomain")]
esc_ctl_subset.head()
esc_tsa_subset = esc_tsa_df[(esc_tsa_df['Probe Ch0'].isin(probes_sel)) & \
                            (esc_tsa_df['roi_type'] == "subdomain")]
esc_tsa_subset.head(70)
# Out:
#                                        Image Name      Date Refractive Index  \
# 1   20191116_RI512_ESC_TSA_62_SIR_THR_42.ome.tiff  20191116            RI512
# 2   20191116_RI512_ESC_TSA_62_SIR_THR_42.ome.tiff  20191116            RI512
# 3   20191116_RI512_ESC_TSA_62_SIR_THR_42.ome.tiff  20191116            RI512
# 5   20191116_RI512_ESC_TSA_32_SIR_THR_15.ome.tiff  20191116            RI512
# 6   20191116_RI512_ESC_TSA_32_SIR_THR_15.ome.tiff  20191116            RI512
# ..                                            ...       ...              ...
# 80  20191116_RI512_ESC_TSA_81_SIR_THR_58.ome.tiff  20191116            RI512
# 81  20191116_RI512_ESC_TSA_81_SIR_THR_58.ome.tiff  20191116            RI512
# 82  20191116_RI512_ESC_TSA_81_SIR_THR_58.ome.tiff  20191116            RI512
# 83  20191116_RI512_ESC_TSA_81_SIR_THR_58.ome.tiff  20191116            RI512
# 84  20191116_RI512_ESC_TSA_81_SIR_THR_58.ome.tiff  20191116            RI512
#
#    Cell Line Name Protocol Probe Ch0 Sir Tag Thresholded Tag  Image Number  \
# 1             ESC      TSA        62     SIR             THR            42
# 2             ESC      TSA        62     SIR             THR            42
# 3             ESC      TSA        62     SIR             THR            42
# 5             ESC      TSA        32     SIR             THR            15
# 6             ESC      TSA        32     SIR             THR            15
# ..            ...      ...       ...     ...             ...           ...
# 80            ESC      TSA        81     SIR             THR            58
# 81            ESC      TSA        81     SIR             THR            58
# 82            ESC      TSA        81     SIR             THR            58
# 83            ESC      TSA        81     SIR             THR            58
# 84            ESC      TSA        81     SIR             THR            58
#
#    Label Ch0  ... solidity  volume volume_units overlap_fraction distance_x  \
# 1   ATTO-565  ...      NaN  0.0150     micron^3              NaN        NaN
# 2   ATTO-565  ...      NaN  0.0320     micron^3              NaN        NaN
# 3   ATTO-565  ...      NaN  0.0598     micron^3              NaN        NaN
# 5   ATTO-565  ...      NaN  0.0098     micron^3              NaN        NaN
# 6   ATTO-565  ...      NaN  0.0130     micron^3              NaN        NaN
# ..       ...  ...      ...     ...          ...              ...        ...
# 80  ATTO-565  ...      NaN  0.0188     micron^3              NaN        NaN
# 81  ATTO-565  ...      NaN  0.0400     micron^3              NaN        NaN
# 82  ATTO-565  ...      NaN  0.0274     micron^3              NaN        NaN
# 83  ATTO-565  ...      NaN  0.0312     micron^3              NaN        NaN
# 84  ATTO-565  ...      NaN  0.0168     micron^3              NaN        NaN
#
#    distance_y distance_z distance3d distance_units                Roi Name
# 1         NaN        NaN        NaN            NaN  ch-0_subdomain_label-2
# 2         NaN        NaN        NaN            NaN  ch-0_subdomain_label-3
# 3         NaN        NaN        NaN            NaN  ch-0_subdomain_label-4
# 5         NaN        NaN        NaN            NaN  ch-0_subdomain_label-2
# 6         NaN        NaN        NaN            NaN  ch-0_subdomain_label-3
# ..        ...        ...        ...            ...                     ...
# 80        NaN        NaN        NaN            NaN  ch-0_subdomain_label-2
# 81        NaN        NaN        NaN            NaN  ch-0_subdomain_label-3
# 82        NaN        NaN        NaN            NaN  ch-0_subdomain_label-4
# 83        NaN        NaN        NaN            NaN  ch-0_subdomain_label-5
# 84        NaN        NaN        NaN            NaN  ch-0_subdomain_label-6
#
# [70 rows x 73 columns]

# %%
pd.concat([esc_ctl_subset, esc_tsa_subset]).boxplot(column="area", by=["Protocol", "Probe Ch0"], rot=45)
# Out:
# <AxesSubplot:title={'center':'area'}, xlabel='[Protocol, Probe Ch0]'>
